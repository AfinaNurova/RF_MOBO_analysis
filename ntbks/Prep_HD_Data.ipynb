# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/TFG/
# Out:
# /content/drive/MyDrive/TFG

# %%
import scipy.io
roi_mat = scipy.io.loadmat('Data_ADNI_TFM/all-data/mat_file.mat', struct_as_record=False, squeeze_me=True)

# %%
roi_mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Sun Dec 10 21:01:23 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'index': array([  752,   753,   754, ..., 88304, 88305, 88347]),
#  'Y': array([[0.00708221, 0.00939385, 0.00255414, ..., 0.06467038, 0.03068803,
#          0.01528519],
#         [0.0509669 , 0.0928716 , 0.04049826, ..., 0.04124855, 0.0209725 ,
#          0.0159112 ],
#         [0.00641272, 0.04249269, 0.0153504 , ..., 0.04236033, 0.02195598,
#          0.01652563],
#         ...,
#         [0.01245288, 0.03353142, 0.01041231, ..., 0.01657722, 0.00396472,
#          0.00356984],
#         [0.01835107, 0.05210776, 0.0104564 , ..., 0.0162119 , 0.00391482,
#          0.00408924],
#         [0.00721914, 0.01426801, 0.00690898, ..., 0.01453996, 0.00349241,
#          0.00356894]]),
#  'path': array([['//research/groups/ADNI/bids/derivatives/CAT12.8.1/sub-ADNI135S6687/ses-M00/anat',
#          'v4_s4_mwp1sub-ADNI135S6687_ses-M00_T1w.nii.gz'],
# ...

# %%
rid = list(roi_mat['RID'])
ses = list(roi_mat['ses'])
img = list(roi_mat['Y'])

# %%
len(rid)
# Out:
# 10565

# %%
import pandas as pd
hd_df = pd.DataFrame(list(zip(rid, ses, img)), columns =['RID', 'ses', 'img'])

# %%
hd_df.head()
# Out:
#     RID ses                                                img
# 0  6687   0  [0.007082205731421709, 0.009393845684826374, 0...
# 1   431  12  [0.05096689611673355, 0.09287159889936447, 0.0...
# 2   431  24  [0.0064127156510949135, 0.042492687702178955, ...
# 3   431   6  [0.018072709441184998, 0.056632090359926224, 0...
# 4   431   0  [2.260049404867459e-05, 0.00014177753473632038...

# %%
hd_df.ses.value_counts()
# Out:
# ses
# 0      2310
# 12     1611
# 6      1471
# 24     1373
# 3       782
# 48      586
# 36      561
# 18      319
# 72      301
# 60      264
# 84      204
# 96      156
# 108      82
# 90       76
# 66       71
# 78       69
# 120      61
# 102      41
# 30       39
# 132      33
# 54       24
# 144      22
# 114      21
# 156      18
# 138      15
# 150      14
# 126      14
# 180       8
# 162       6
# 42        5
# 168       4
# 174       2
# 186       2
# Name: count, dtype: int64

# %%
hd_df.dtypes
# Out:
# RID    object
# ses    object
# img    object
# dtype: object

# %%
hd_df['ses'] = hd_df['ses'].astype(int)

# %%
hd_df_filtered = hd_df[hd_df['ses'] == 0]

# %%
hd_df_filtered.head()
# Out:
#      RID  ses                                                img
# 0   6687    0  [0.007082205731421709, 0.009393845684826374, 0...
# 4    431    0  [2.260049404867459e-05, 0.00014177753473632038...
# 7    446    0  [0.07818212360143661, 0.08181332796812057, 0.0...
# 11  2324    0  [1.1395356523280498e-05, 7.58579553803429e-05,...
# 15  5099    0  [0.0006542991031892598, 0.0018743590917438269,...

# %%
# hd_df_filtered.to_parquet('/content/drive/MyDrive/TFG/data/baseline_hd_df.parquet', engine='pyarrow')

# %%
import pandas as pd
hd = pd.read_parquet('/content/drive/MyDrive/TFG/data/baseline_hd_df.parquet', engine='pyarrow')

# %%
with open(f"cerebro.txt", "w") as f:
    f.write(", ".join(map(str, hd.loc[0, 'img'])))

# %%
hd.shape
# Out:
# (2310, 3)
